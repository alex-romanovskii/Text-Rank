# %%
from TextRank import * 
for path in path_list:
    name=path.split('\\')[1].split('.txt')[0]
    text_file=open(path, 'r').read()
    result=textrank(text_file,name)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
result
# Out:
#     Index                                           Sentence    Weight
# 0       0  Christmas Day is one of the most favorite Amer...  0.316410
# 1       1  Christmas is a Christian holiday marking the b...  0.282360
# 2       2  Decorating houses and yards with lights, putti...  0.689969
# 3       3  The tradition of placing a decorated tree in t...  1.000000
# 4       4  The Presidentג€™s grandchildren young Benjamin...  0.657080
# 5       5                           It was lit with candles.  0.000000
# 6       6             Filled stockings hung from the mantel.  0.032611
# 7       7  Presents, candy and nuts were distributed to f...  0.133240
# 8       8  President Harrison gave turkeys and gloves to ...  0.237159
# 9       9  He received a silver-dollar-shaped picture hol...  0.127377
# 10     10  What began as a family gathering has become a ...  0.305556
# 11     11  Over the years, the White House Christmas tree...  0.839523
# ...
